# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/indian_liver_patient.csv')
df
# Out:
#      Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0     65  Female              0.7               0.1                   187
# 1     62    Male             10.9               5.5                   699
# 2     62    Male              7.3               4.1                   490
# 3     58    Male              1.0               0.4                   182
# 4     72    Male              3.9               2.0                   195
# ..   ...     ...              ...               ...                   ...
# 578   60    Male              0.5               0.1                   500
# 579   40    Male              0.6               0.1                    98
# 580   52    Male              0.8               0.2                   245
# 581   31    Male              1.3               0.5                   184
# 582   38    Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# ...

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df)
# Out:
# https://docs.google.com/spreadsheets/d/19wif1V6Gy_-Nj40324T65-JlY5H9r5sKYHGn7MvYf-I/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/19wif1V6Gy_-Nj40324T65-JlY5H9r5sKYHGn7MvYf-I/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
df.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  Female              0.7               0.1                   187
# 1   62    Male             10.9               5.5                   699
# 2   62    Male              7.3               4.1                   490
# 3   58    Male              1.0               0.4                   182
# 4   72    Male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Dataset
# 0      3.3                        0.90        1
# ...

# %%
df.tail()
# Out:
#      Age Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 578   60   Male              0.5               0.1                   500
# 579   40   Male              0.6               0.1                    98
# 580   52   Male              0.8               0.2                   245
# 581   31   Male              1.3               0.5                   184
# 582   38   Male              1.0               0.3                   216
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 578                        20                          34             5.9
# 579                        35                          31             6.0
# 580                        48                          49             6.4
# 581                        29                          32             6.8
# 582                        21                          24             7.3
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# ...

# %%
df.sample(5)
# Out:
#      Age Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 113   74   Male              0.6               0.1                   272
# 551   29   Male              1.2               0.4                   160
# 437   35   Male              1.6               0.7                   157
# 236   22   Male              0.8               0.2                   300
# 456   32   Male              0.7               0.2                   189
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 113                        24                          98             5.0
# 551                        20                          22             6.2
# 437                        15                          44             5.2
# 236                        57                          40             7.9
# 456                        22                          43             7.4
#
#      Albumin  Albumin_and_Globulin_Ratio  Dataset
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         583 non-null    int64
#  1   Gender                      583 non-null    object
#  2   Total_Bilirubin             583 non-null    float64
#  3   Direct_Bilirubin            583 non-null    float64
#  4   Alkaline_Phosphotase        583 non-null    int64
#  5   Alamine_Aminotransferase    583 non-null    int64
#  6   Aspartate_Aminotransferase  583 non-null    int64
#  7   Total_Protiens              583 non-null    float64
#  8   Albumin                     583 non-null    float64
#  9   Albumin_and_Globulin_Ratio  579 non-null    float64
#  10  Dataset                     583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %%
df[['Gender','Dataset']]=df[['Gender','Dataset']].astype('category')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         583 non-null    int64
#  1   Gender                      583 non-null    category
#  2   Total_Bilirubin             583 non-null    float64
#  3   Direct_Bilirubin            583 non-null    float64
#  4   Alkaline_Phosphotase        583 non-null    int64
#  5   Alamine_Aminotransferase    583 non-null    int64
#  6   Aspartate_Aminotransferase  583 non-null    int64
#  7   Total_Protiens              583 non-null    float64
#  8   Albumin                     583 non-null    float64
#  9   Albumin_and_Globulin_Ratio  579 non-null    float64
#  10  Dataset                     583 non-null    category
# dtypes: category(2), float64(5), int64(4)
# memory usage: 42.5 KB

# %%
df.describe()
# Out:
#               Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count  583.000000       583.000000        583.000000            583.000000
# mean    44.746141         3.298799          1.486106            290.576329
# std     16.189833         6.209522          2.808498            242.937989
# min      4.000000         0.400000          0.100000             63.000000
# 25%     33.000000         0.800000          0.200000            175.500000
# 50%     45.000000         1.000000          0.300000            208.000000
# 75%     58.000000         2.600000          1.300000            298.000000
# max     90.000000        75.000000         19.700000           2110.000000
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# count                583.000000                  583.000000      583.000000
# mean                  80.713551                  109.910806        6.483190
# ...

# %% [markdown]
# #UNIVARIATE ANALYSIS

# %% [markdown]
# #AGE

# %%
df['Age'].describe()
# Out:
# count    583.000000
# mean      44.746141
# std       16.189833
# min        4.000000
# 25%       33.000000
# 50%       45.000000
# 75%       58.000000
# max       90.000000
# Name: Age, dtype: float64

# %%
sns.kdeplot(df['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
df['Age'].skew() #left skewed slightly almost symmetrical
# Out:
# np.float64(-0.029385312710346265)

# %%
df['Age'].plot(kind='box') #No outliers present in the data
# Out:
# <Axes: >

# %%
df['Age'].isnull().sum() #no null values present in this column
# Out:
# np.int64(0)

# %% [markdown]
# #Total Bilirubin

# %%
df['Total_Bilirubin'].describe()
# Out:
# count    583.000000
# mean       3.298799
# std        6.209522
# min        0.400000
# 25%        0.800000
# 50%        1.000000
# 75%        2.600000
# max       75.000000
# Name: Total_Bilirubin, dtype: float64

# %% [markdown]
# #The difference between the 75 percentile value and the max value is very large so a possibility of incorrect entry or an extreme outlier in the data

# %%
df['Total_Bilirubin'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Total_Bilirubin'].skew() #highly right skewed
# Out:
# np.float64(4.90747399372197)

# %%
sns.boxplot(df['Total_Bilirubin'])
# Out:
# <Axes: ylabel='Total_Bilirubin'>

# %%
df[df['Total_Bilirubin']>30]
# Out:
#      Age Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 166   55   Male             75.0               3.6                   332
# 259   42   Male             30.5              14.2                   285
# 504   32   Male             30.5              17.1                   218
# 505   32   Male             32.6              14.1                   219
# 531   40   Male             30.8              18.3                   285
# 559   26   Male             42.8              19.7                   390
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 166                        40                          66             6.2
# 259                        65                         130             5.2
# 504                        39                          79             5.5
# 505                        95                         235             5.8
# 531                       110                         186             7.9
# ...

# %%
df['Total_Bilirubin'] = df['Total_Bilirubin'].where(df['Total_Bilirubin'] <= 32.6, np.nan) #masking

# %%
df['Total_Bilirubin'].isnull().sum()
# Out:
# np.int64(2)

# %% [markdown]
# #Direct_Bilirubin

# %%
df['Direct_Bilirubin'].describe()
# Out:
# count    583.000000
# mean       1.486106
# std        2.808498
# min        0.100000
# 25%        0.200000
# 50%        0.300000
# 75%        1.300000
# max       19.700000
# Name: Direct_Bilirubin, dtype: float64

# %%
df=df[df['Direct_Bilirubin']!=19.7]

# %%
#we see its the same person so better to remove that row itself
df['Direct_Bilirubin']
# Out:
# 0      0.1
# 1      5.5
# 2      4.1
# 3      0.4
# 4      2.0
#       ...
# 578    0.1
# 579    0.1
# 580    0.2
# 581    0.5
# 582    0.3
# Name: Direct_Bilirubin, Length: 582, dtype: float64

# %%
df.describe()
# Out:
#               Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count  582.000000       581.000000        582.000000            582.000000
# mean    44.778351         3.107401          1.454811            290.405498
# std     16.185053         5.205792          2.707261            243.111919
# min      4.000000         0.400000          0.100000             63.000000
# 25%     33.000000         0.800000          0.200000            175.250000
# 50%     45.000000         1.000000          0.300000            208.000000
# 75%     58.000000         2.600000          1.300000            298.000000
# max     90.000000        32.600000         18.300000           2110.000000
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# count                582.000000                  582.000000      582.000000
# mean                  80.723368                  109.862543        6.481443
# ...

# %%
df['Direct_Bilirubin'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Direct_Bilirubin'].skew() #positively skewed
# Out:
# np.float64(3.101478930755727)

# %%
df['Direct_Bilirubin'].kurtosis()
# Out:
# np.float64(10.234888175507145)

# %%
df['Direct_Bilirubin'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['Direct_Bilirubin']==18.3] #can't remove as values maybe true
# Out:
#      Age Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 531   40   Male             30.8              18.3                   285
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 531                       110                         186             7.9
#
#      Albumin  Albumin_and_Globulin_Ratio Dataset
# 531      2.7                         0.5       1

# %% [markdown]
# #Alkaline Phosphate

# %%
df['Alkaline_Phosphotase'].describe()
# Out:
# count     582.000000
# mean      290.405498
# std       243.111919
# min        63.000000
# 25%       175.250000
# 50%       208.000000
# 75%       298.000000
# max      2110.000000
# Name: Alkaline_Phosphotase, dtype: float64

# %%
df[df['Alkaline_Phosphotase']==2110]
# Out:
#      Age Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 233   33   Male              2.0               1.4                  2110
#
#      Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 233                        48                          89             6.2
#
#      Albumin  Albumin_and_Globulin_Ratio Dataset
# 233      3.0                         0.9       1

# %% [markdown]
# #Medically possible especially for these cases
# Obstructive / cholestatic liver disease (bile flow blockage)
#
# Possibly biliary cirrhosis or stone in bile duct
#
# The mild increase in ALT/AST supports cholestatic pattern, not pure hepatocellular injury.

# %%
df['Alkaline_Phosphotase'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Alkaline_Phosphotase'].skew()
# Out:
# np.float64(3.7655171128947282)

# %%
df['Alkaline_Phosphotase'].kurtosis()
# Out:
# np.float64(17.740049345262978)

# %%
df['Alkaline_Phosphotase'].plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# #Rest of the other columns look fine without any abnormal value so we just analyse them

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Total_Bilirubin', 'Direct_Bilirubin',
#        'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
#        'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin',
#        'Albumin_and_Globulin_Ratio', 'Dataset'],
#       dtype='object')

# %%
list=['Alamine_Aminotransferase',
       'Aspartate_Aminotransferase', 'Total_Protiens', 'Albumin',
       'Albumin_and_Globulin_Ratio']

# %%
for col in list:
    plt.figure(figsize=(6,4))
    df[col].plot(kind='kde', color='teal')
    plt.title(f'KDE Plot of {col}')
    plt.xlabel(col)
    plt.ylabel('Density')
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.show()

# %%
for col in list:
    skew = df[col].skew()
    kurt = df[col].kurtosis()

    print(f"{col}:")
    print(f"  Skewness  = {skew:.3f}")
    print(f"  Kurtosis  = {kurt:.3f}")
    print("-" * 40)
# Out:
# Alamine_Aminotransferase:
#   Skewness  = 6.543
#   Kurtosis  = 50.487
# ----------------------------------------
# Aspartate_Aminotransferase:
#   Skewness  = 10.538
#   Kurtosis  = 150.670
# ----------------------------------------
# Total_Protiens:
#   Skewness  = -0.283
#   Kurtosis  = 0.234
# ----------------------------------------
# Albumin:
#   Skewness  = -0.047
#   Kurtosis  = -0.388
# ----------------------------------------
# Albumin_and_Globulin_Ratio:
#   Skewness  = 0.994
#   Kurtosis  = 3.297
# ----------------------------------------

# %%
for col in list:
    plt.figure(figsize=(6,3))
    sns.boxplot(x=df[col], color='lightcoral')
    plt.title(f'Boxplot of {col}')
    plt.xlabel(col)
    plt.grid(True, linestyle='--', alpha=0.6)
    plt.show()

# %%
df.to_csv('cleaned_data_1.csv', index=False)

# %%
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               1
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    4
# Dataset                       0
# dtype: int64
